# %%
import csv
import re
import pandas as pd
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import numpy as np
from sklearn.model_selection import KFold

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Include this block so that keras 
# # would not use up all the GPU memory.
# from keras.backend.tensorflow_backend import set_session
# import tensorflow as tf
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
# # config.log_device_placement = True  # to log device placement (on which device the operation ran)
# sess = tf.Session(config=config)
# set_session(sess)  # set this TensorFlow session as the default session for Keras

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')

# %%
datafiles_path = './data/drug_sentence_classification.csv'
data_files = pd.read_csv(datafiles_path)

# %%
data_files.head()
# Out:
#     neutral_citation  sentence_id  important  \
# 0  [2009] HKCFI 2104            0      False
# 1  [2009] HKCFI 2104            1      False
# 2  [2009] HKCFI 2104            2      False
# 3  [2009] HKCFI 2104            3      False
# 4  [2009] HKCFI 2104            4      False
#
#                                             sentence
# 0  ##  HKSAR v. MWANIKI, CATHERINE WAITHIRA [2009...
# 1                                       HCCC241/2008
# 2                           IN THE HIGH COURT OF THE
# 3            HONG KONG SPECIAL ADMINISTRATIVE REGION
# 4                            COURT OF FIRST INSTANCE

# %%
datas_X = data_files['sentence']
datas_Y = data_files['important'].astype(int)

# %%
datas_X.head()
# Out:
# 0    ##  HKSAR v. MWANIKI, CATHERINE WAITHIRA [2009...
# 1                                         HCCC241/2008
# 2                             IN THE HIGH COURT OF THE
# 3              HONG KONG SPECIAL ADMINISTRATIVE REGION
# 4                              COURT OF FIRST INSTANCE
# Name: sentence, dtype: object

# %%
datas_Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: important, dtype: int64

# %%
data_example = datas_X[0]
data_example
# Out:
# '##  HKSAR v. MWANIKI, CATHERINE WAITHIRA [2009] HKCFI 2104; HCCC 241/2008 (30\r\nMarch 2009)'

# %%
type(data_example)
# Out:
# str

# %%
#Clean up the data

#Function to clean up data
#•Only take characters inside A-Za-z
#•remove stop words
#•lemmatize

# %%
lemmatizer = WordNetLemmatizer()
strip_special_chars = re.compile("[^A-Za-z0-9 ]+")
stop_words = set(stopwords.words("english"))

def cleanUpSentence(r, stop_words = None):
    r = r.lower().replace("<br />", " ")
    r = re.sub(strip_special_chars, "", r.lower())
    if stop_words is not None:
        words = word_tokenize(r)
        filtered_sentence = []
        for w in words:
            w = lemmatizer.lemmatize(w)
            if w not in stop_words:
                if any(map(str.isdigit, w)):
                    filtered_sentence.append("0")
                else:
                    filtered_sentence.append(w)
        return " ".join(filtered_sentence)
    else:
        return r

# %%
totalX = []
totalY = np.array(datas_Y).reshape((-1,1))
for i, doc in enumerate(datas_X):
    #直接在这里去除\n，防止\n可能会让两句话连接处的两个单词连在一起
    doc = doc.replace("\n"," ")
    totalX.append(cleanUpSentence(doc, stop_words))

# %%
# totalX=np.array(totalX)
# emptyX,emptyY,totalX,totalY = totalX[totalX==''],totalY[totalX==''],totalX[totalX!=''],totalY[totalX!='']

# %%
totalX
# Out:
# ['hksar v mwaniki catherine waithira 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v mwaniki catherine waithira',
#  '',
#  'deputy high court judge geiser',
#  'date 0 march 0 0',
#  'present',
#  'miss grace chan spp department justicefor hksar mr frederic c whitehouse instructed chin associate 0 accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court madam pleaded guilty offence trafficking dangerous drug contrary section 0 0 dangerous drug ordinance cap 0 law hong kong particular 0 june last year chek lap kok international airport possession 0 gramme mixture containing 0 gramme heroin hydrochloride',
#  'fact agreed indicate upon arrival hong kong international airport searched quantity heroin form pellet found inside pant wearing subsequently taken hospital 0 pellet heroin discharged body',
#  'told police record interview recruited person called mike mumbai collect drug delhi bring hong kong',
#  'delhi met another male called joe gave pellet swallow brought hong kong',
#  'paid 0 successful delivery hong kong',
#  'read letter written ha handed counsel mr whitehouse',
#  'make tragic reading',
#  '0 year age clear record single mother three child',
#  'also understand responsibility looking seven child four nephew three niece',
#  'child two sister together respective husband died aid',
#  'addition add overwhelming difficulty shop home burnt postelection riot took place kenya end 0',
#  'result desperate situation say letter easy prey marauding drug boss brought cartel',
#  'asked counsel take matter account sentencing',
#  'also give credit plea guilty offence indication genuine remorse',
#  'must however also bear mind aggravating feature quite obviously international element offence sense large quantity drug wa brought hong kong overseas',
#  'sentencing guideline contained regina v lau tak ming others 0 hklr 0 put outside 0 0 starting point bracket possession 0 gramme heroin',
#  'prepared however invoke starting point keep within sentencing bracket due aggravating feature referred find unable adopt starting point le 0 year imprisonment',
#  'indeed adopt starting point',
#  'discount starting point onethird take account plea guilty coming 0 year 0 month imprisonment',
#  'addition act mercy give discount 0 month imprisonment take account tragic circumstance found leading commit offence arriving sentence 0 year imprisonment',
#  'hksar v lai chi wai 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v lai chi wai',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date 0 march 0 0',
#  'present',
#  'mr jonathan edward actonbond fiat hksar mr andrew humphrey bullet instructed director legal aid accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court lai chiwai know trafficking type dangerous drug rightly considered serious criminal offence',
#  'maximum penalty provided law one life prison',
#  'court appeal ha long said heavy penalty imposed person way engage filthy trade',
#  'court appeal ha also set clear guideline judge magistrate sentence drug trafficker',
#  'judge magistrate expected follow guideline unless strong reason',
#  'strong reason case',
#  'prepared accept intention relation ketamine wa give away friend acquaintance',
#  'nevertheless giving away dangerous drug still trafficking',
#  'nothing background circumstance commission two crime mitigating value',
#  'excuse intended use proceeds sale cocaine help pay elder brother debt',
#  'mitigation powerful mitigation cooperation police plea guilty morning',
#  'plea guilty certainly show realism part acceptance inevitable also extent indicate degree remorse',
#  'entitled expect receive reduction sentence guilty plea',
#  'two drug trafficked cocaine far serious one',
#  'scourge cocaine known throughout world',
#  'illicit use hong kong becoming common damaging effect take society general recognised severe damaging effect caused heroin',
#  'ketamine recognised le harmful drug',
#  'nevertheless rightly regarded dangerous drug controlled',
#  'quite anyone would want take drug one whose main lawful us tranquillise horse idea',
#  'following guideline already spoken length sentence judge expected pas drug trafficker cocaine offence second two charge face mean would facing prison sentence least 0 year found guilty offence trial',
#  'ketamine offence first two count trial sentence 0 year imprisonment would amply justified',
#  'course total sentence 0 year two offence would regarded excessively high two offence',
#  'reduction overall sentence 0 year imprisonment trial would justified',
#  'starting point sentence taking calculating sentence',
#  'taking account guilty plea reducing overall sentence one 0 year imprisonment discount onethird',
#  'individual sentence passed two offence follows',
#  '0 count trafficking cocaine sentence one 0 year 0 month imprisonment onethird discount 0 year',
#  '',
#  '0 count trafficking ketamine sentence one 0 year 0 month imprisonment onethird discount 0 year sentence trial',
#  'ordering sentence 0 count trafficking cocaine partly consecutive sentence 0 count trafficking ketamine',
#  'start serve sentence 0 count served first 0 month sentence 0 count',
#  'mean total period imprisonment one 0 year',
#  'hksar v virginia penaranda borras 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v virginia penaranda borras',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date 0 march 0 0',
#  'present',
#  'mr james h mcgowan fiat hksar mr graeme mackay instructed messrs krishnan tsang assigned director legal aid accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court virginia borras stand',
#  'must aware trafficking dangerous drug country world indeed different country world serious offence',
#  'told mr mackay hong kong heavy prison sentence passed people way engage filthy trade',
#  'regarded hong kong serious maximum penalty life imprisonment',
#  'country asia maximum penalty death',
#  'mr mackay told clear guideline laid judge court appeal hong kong sentence must pas people engage drug trafficking',
#  'told quite sure judge expected stick guideline unless strong reason',
#  'tell case strong reason permit depart guideline',
#  'aware say kuala lumpur threatened man call black man bullied say taking drug hong kong',
#  'regard story certain degree caution',
#  'bear mind easy people make story like almost impossible prosecuting authority way disprove truth',
#  'clearly must met somebody kuala lumpur persuaded way bring drug hong kong',
#  'persuaded swallow hide private part',
#  'however said careful come consider circumstance persuaded',
#  'note clear record',
#  'never trouble police court either hong kong far known country',
#  'frankly engage drug trafficking previous clear record count little',
#  'doe help extent fact given hong kong authority background information may use future',
#  'bear mind background information able give',
#  'powerful mitigation fact pleaded guilty cooperative hong kong authority',
#  'mr mackay told entitled substantial discount sentence would received convicted trafficking dangerous drug trial',
#  'quantity dangerous drug trafficked wa mixture weighing 0 gramme 0 gramme heroin trial pleaded guilty matter gone trial jury found guilty could looking sentence high 0 year imprisonment',
#  'taking view case found guilty jury taking account little know taking account story say happened kuala lumpur taking account fact since conviction cooperative police trial sentence 0 year imprisonment would appropriate',
#  'plea guilty permitted reduce considerably',
#  'reducing onethird',
#  'sentence imprisonment offence one 0 year 0 month imprisonment',
#  'told get prison sentence served worked earliest release date hong kong law',
#  'hksar v wong chi hung 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v wong chihung',
#  '',
#  'honourable mr justice v bokhary',
#  'date 0 march 0 0',
#  'present',
#  'mr harish melwaney spp department justice hksar mr wu kamfun roderick instructed legal aid department accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court accused stand convicted one charge trafficking dangerous drug',
#  'credit stand convicted plea guilty',
#  'quantity involved 0 gramme crystalline solid containing 0 gramme methamphetamine hydrochloride commonly known ice',
#  'view appropriate starting point quantity ice 0 year imprisonment',
#  '0 year old although trouble wa time ago',
#  'taken account everything ha urged behalf counsel read letter shall give full credit plea guilty',
#  'circumstance sentence 0 year imprisonment',
#  'hksar v lo kwun fung 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v lo kwunfung',
#  '',
#  'deputy high court judge toh',
#  'date 0 march 0 0',
#  'present',
#  'mr vincent wong spp department justice hksar mr leung chunkeung instructed legal aid department accused',
#  'offence trafficking dangerous drug etc',
#  '',
#  'transcript audio recording sentence case',
#  'court defendant please stand',
#  'defendant ha pleaded guilty magistrate court three count trafficking dangerous drug one court resisting police officer due execution duty',
#  'fact quite simple',
#  '0 april last year defendant wa driving car accelerated car upon seeing police',
#  'police managed subsequently stop defendant car',
#  'initial search person drug charge 0 wa found left rear pocket trouser',
#  'wa subsequently found total crystalline solid 0 gramme containing 0 gramme methamphetamine hydrochloride',
#  'time defendant put fierce struggle',
#  'subsequently wa subdued',
#  'wa subject matter 0 charge resisting police officer',
#  'subsequently search wa conducted eight packet dangerous drug found inside car subject matter 0 charge',
#  'wa total 0 gramme containing 0 gramme methamphetamine hydrochloride',
#  'defendant seized exhibit taken police station',
#  'inside police station thorough body search wa conducted defendant police found 0 packet dangerous drug inside defendant underwear subject matter 0 charge',
#  '0 gramme crystalline solid containing 0 gramme methamphetamine hydrochloride',
#  'defendant aged 0 ha 0 previous conviction two dangerous drug',
#  'one wa possession dangerous drug wa 0 year old second one wa 0 wa sent datc possession dangerous drug',
#  'mr leung pointed first trafficking dangerous drug offence',
#  'motivation committing present offence told owes money money lender',
#  'main mitigating factor behalf defendant pleaded guilty earliest opportunity',
#  'said defendant pleaded guilty magistrate court wa committed high court sentencing',
#  'indication remorse also strong mitigating factor present matter heard chamber',
#  'good indication remorse defendant',
#  'sentencing tariff trafficking methamphetamine hydrochloride commonly known ice wa laid case ching kwok hung recommended trafficking amount 0 0 gramme would merit sentence 0 0 year',
#  'case total amount drug three charge amounted 0 gramme methamphetamine hydrochloride would merit starting point 0 year',
#  'said mitigating factor agree mr leung discount one 0 per cent',
#  'thus count 0 0 0 defendant sentenced 0 year 0 month imprisonment charge served concurrently',
#  '0 charge resisting police officer execution duty starting point sentence 0 week reduced 0 week mitigating circumstance',
#  '0 week served concurrent sentence 0 year 0 month',
#  'defendant go prison 0 year 0 month',
#  'hksar v cheng wai hung others 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v cheng waihung 0 lee siuchung 0',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date 0 march 0 0',
#  'present',
#  'fung meiki mickey fiat hksar mr hanif mughal instructed messrs mui kwan 0 accused mr p loftus instructed messrs william sin 0 accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court cheng waihung lee siuchung please stand',
#  'clear police burst dangerous drug packing workshop heavily engaged work packing ketamine smaller quantity',
#  'law hong kong regard trafficking type dangerous drug serious criminal offence much maximum penalty offence life imprisonment',
#  'ketamine relatively new dangerous drug hong kong',
#  'quite idea legitimate use tranquillising horse',
#  'nevertheless ha become common drug abuse particularly young men woman',
#  'many young people become habitual user filthy substance',
#  'regarded schedule 0 drug',
#  'recently court appeal laid clear guideline judge sentence people traffic ketamine expected stick guideline',
#  'court appeal say people convicted trafficking ketamine weight active quantity ketamine substance range 0 0 gramme sentence trial conviction jury 0 0 year imprisonment imposed',
#  'court appeal ha made clear sentence imposed trial people pleaded guilty found guilty jury',
#  'court appeal leaf open judge within range 0 0 year sentence offender',
#  'regard active weight ketamine trafficked told respective counsel morning accept part ketamine dealing wa probably consumption',
#  'prepared accept would shared others either payment possibly cost',
#  'doubt however perhaps larger quantity wa sold profit',
#  'however decided taken matter trial convicted jury would taken starting point sentence 0 year imprisonment',
#  'nothing personal circumstance find mitigating value',
#  'longer teenager mean men extreme youth',
#  '0 early 0',
#  'treating equally guilty',
#  'fact cheng waihung criminal record little relevance marginal mitigating value dangerous drug case',
#  'know lee siuchung one previous conviction possession dangerous drug ketamine needle say served probation order',
#  'said treating equally guilty increasing lee sentence previous conviction',
#  'counsel said morning mitigation real mitigation fact realistically pleaded guilty offence',
#  'saved police trouble time expense well court trouble time expense',
#  'well established people admit guilt court receive substantial discount sentence would otherwise received',
#  'already said found guilty jury offence would sentenced one 0 year imprisonment',
#  'would amply justified guideline court appeal laid judge follow',
#  'plea guilty permitted reduce sentence onethird',
#  'mathematics correct always stand corrected counsel result receiving sentence 0 year 0 month offence',
#  'sentence receive offence',
#  'hksar v chu pak cheung 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chu pakcheung',
#  '',
#  'deputy high court judge mackintosh',
#  'date 0 march 0 0',
#  'present',
#  'mr vincent wong spp department justice hksar mr bernard yuen assigned director legal aid accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court chu pakcheung stand please',
#  'pleaded guilty magistrate 0 february trafficking dangerous drug quantity ketamine 0 gramme contained larger amount powder',
#  'street value somewhere around 0',
#  'said delivering somebody else 0',
#  'basis sentencing offence trafficking',
#  'evidence drug brought hong kong would aggravation',
#  'doubt told sentencing trafficking dangerous drug based always upon guideline laid court appeal',
#  'following guideline sentence calculated according quantity dangerous drug trafficked case 0 gramme ketamine',
#  'reason must explain many case drug trafficking come court many different offender many different background',
#  'essential different offender sentenced consistent fair way ensures sentence eventually imposed upon based upon criterion every case',
#  'sentencing court must follow guideline',
#  'insofar ketamine concerned serious problem exists hong kong misuse ketamine june 0 court appeal set new guideline sentence guideline apply case',
#  'sure told fall within category sentencing 0 0 gramme ketamine court appeal ha laid sentence 0 0 year imprisonment trial discount mitigation imposed',
#  'recognise ha emphasised behalf mr yuen fact young man 0 today 0 time committed offence',
#  'clear record',
#  'material today including raft letter support presence people court today lot show wicked young man seriously misguided young man',
#  'tragedy recognised people court today become involved commission serious crime',
#  'clear whats said young man wa drifting time',
#  'got new course time committed offence',
#  'easy target cynical evil drug trafficker always ready exploit nave young man',
#  'course point view must seemed easy money deliver package',
#  'one could fail moved expression support letter sincerely expressed people signed many today',
#  'course already indicated mr yuen behalf treat somebody extremely young young teenager sometimes court take different approach 0',
#  'discount sentence reflect mitigation available start course plea guilty earliest opportunity genuine remorse previous good character',
#  'discount give exceed onethird starting point must take',
#  'hope support thats expressed today various material placed continues throughout time custody come stronger better able resist sort temptation wa placed front case',
#  'even discount take starting point sentence still heavy sentence recognise satisfied alternative impose heavy sentence',
#  'must case take starting point sentence 0 year imprisonment reduce 0 year reflect mitigation referred',
#  'hksar v lee tsz fung 0 hkcfi 0 hccc 0 0 march 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v lee tszfung',
#  '',
#  'hon mcmahon j',
#  'date 0 march 0 0',
#  'present',
#  'mr f whitehouse counsel fiat hksar mr chris cheung instructed martin law co accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court stand please mr lee',
#  '0 defendant pleaded guilty offence trafficking 0 gramme ketamine',
#  '0 september 0 defendant intercepted police anti drug operation car park residential block tin shui wai',
#  'drug found bag wa carrying',
#  'offence occurred several month new guideline set secretary justice v hii siew cheng criminal appeal application review 0 promulgated',
#  'view guideline apply fully case given period elapsed publication occurrence offence',
#  'take starting point sentence 0 year imprisonment',
#  'material mitigation available defendant plea guilty',
#  'regard entitled full discount',
#  'sentence defendant 0 year 0 month imprisonment',
#  'hksar v chan wai man 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chan waiman',
#  '',
#  'honourable mr justice v bokhary',
#  'date 0 april 0 0',
#  'present',
#  'laura ng spp department justice hksar mr chow pakchu peter instructed legal aid department accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court accused stand convicted one charge trafficking dangerous drug',
#  'pleaded guilty magistrate court committed sentenced today high court',
#  'quantity drug involved 0 gramme powder containing 0 gramme ketamine',
#  'view appropriate starting point quantity drug 0 year imprisonment',
#  '0 year old trouble',
#  'taken account everything ha urged behalf counsel particularly plea guilty cooperation police providing information prepared give full onethird discount case',
#  'therefore sentenced 0 year imprisonment',
#  'hksar v wai sai ho benson 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v wai saiho benson',
#  '',
#  'honourable mr justice v bokhary',
#  'date 0 april 0 0',
#  'present',
#  'mr peter power spp department justice hksar mr charles chan instructed legal aid department accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court accused stand convicted one charge trafficking dangerous drug',
#  'credit stand convicted plea guilty magistrate court',
#  'quantity involved 0 gramme powder containing 0 gramme ketamine',
#  'view appropriate starting point quantity ketamine suggested counsel 0 year',
#  'taken account everything ha urged behalf counsel particularly plea guilty early stage',
#  'also read letter written court',
#  'circumstance sentence 0 year imprisonment',
#  'hksar v li fuk keung 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar',
#  'v',
#  'li fukkeung',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date 0 april 0 0',
#  'present',
#  'mr vincent wong spp department justice hksar mr ronald mayne instructed legal aid department accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court li fukkeung stand please',
#  'li fukkeung listened carefully mr mayne ha said behalf said said respect',
#  'also read two report ordered also read mother letter letter court',
#  'accept problem came lack adequate parental control young',
#  'seems told read mother love supportive',
#  'going need mother support',
#  'wa wrong wa foolish',
#  'drug trafficking particularly heavy drug ketamine regarded heavy drug serious criminal offence',
#  'serious legislature ha set maximum penalty life imprisonment',
#  'know mr mayne told court appeal set guideline judge sentence people traffic dangerous drug including ketamine',
#  'also told expected stick guideline unless exceptional circumstance regret tell exceptional circumstance case',
#  'age 0 go small way mitigating offence',
#  'law court regard young men 0 adult',
#  'adult responsible action',
#  'clearly told plan going vast quantity ketamine',
#  'trafficked large quantity ketamine 0 kilogram stuff',
#  'offence serious contemplate making subject detention centre order training centre order',
#  'fact hitherto clear record count little drug trafficking case',
#  'real mitigation mr mayne said early plea guilty magistrate court',
#  'indicates remorse accept remorseful',
#  'perhaps importantly show realism part acceptance inevitable',
#  'pleading guilty earned substantial discount sentence would received trial',
#  'following guideline spoken revised court appeal june last year three month committed offence trial pleaded guilty found guilty jury would looking sentence least 0 year imprisonment possibly',
#  'taking 0 year starting point decide sentence',
#  'plea guilty cooperation entitled onethird reduction 0 year take 0 year 0 month',
#  'reducing sentence 0 month take account age fact criminal record',
#  'take pleasure sentencing young men offence duty tell sentence imprisonment one 0 year imprisonment',
#  'proceeding sentence required',
#  'court adjourns 0',
#  'court resume 0',
#  'accused present',
#  'appearance',
#  'proceeding sentence correction required',
#  'court stand please',
#  'owe apology',
#  'made miscalculation',
#  'sentence said would starting point 0 year',
#  'onethird discount plea guilty take 0 year 0 month',
#  'incorrectly said 0 year 0 month',
#  'reduced sentence 0 month young age clear record making clear sentence one 0 year 0 month',
#  'hksar v chan wai yin 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chan waiyin',
#  '',
#  'deputy high court judge line',
#  'date 0 april 0 0',
#  'present',
#  'sally yam spp department justice hksar mr david khosa assigned director legal aid accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court stand please',
#  'sentence trafficking dangerous drug',
#  'drug wa ketamine trafficking 0 gramme',
#  'know perfectly well sentence case like depend guideline turn based upon nature drug quantity',
#  'amount carried attracts starting point 0 0 year',
#  'one proceed entirely mathematically starting point would region 0 short',
#  'mitigation available take bracket little discretion left within',
#  'given limit discretion real choice case whether go prison onethird discount 0 year 0 year 0 month',
#  'circumstance going say 0 year',
#  'soft hope people traffic ketamine',
#  'read letter handed behalf one wrote discern genuine remorse',
#  'bear mind young daughter',
#  'remind aggravating feature attached crime',
#  'end judge 0 year adequate punishment',
#  'hksar v lam mei ching bet 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar',
#  'v',
#  'lam mei ching bet',
#  '',
#  'dhcj longley',
#  'date 0 april 0 0',
#  'present',
#  'mickey fung spp department justice hksar mr andrew raffell instructed c k mok co accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court lam meiching pleaded guilty trafficking 0 gramme crystalline solid containing 0 gramme methamphetamine hydrochloride',
#  'drug found 0 ziplock bag placed inside underpants searched custom returning mainland lo wu 0 october last year',
#  'set mainland earlier day',
#  'estimated street value drug wa 0',
#  'see record involved drug user many year never convicted offence trafficking',
#  'prepared accept persuaded carry drug occasion order satisfy debt owed person induced carry exercise',
#  'however doubt carrying substantial quantity drug serious consequence would follow caught',
#  'case illusion carrying le drug actually',
#  'circumstance bearing mind quantity drug appropriate starting point view 0 year imprisonment',
#  'listened carefully ha said behalf mr raffell well taking account plea guilty',
#  'taking matter account prepared reduce sentence one 0 year imprisonment sentence pas',
#  '',
#  'hksar v pang sau lan 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar pang saulan',
#  '',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court 0 september last year 0 pm defendant hong kong resident reentered hong kong lok chau control point new territory',
#  'examination counter custom arrival hall wa searched paper bag wa found handbag',
#  'inside paper bag wa another plastic zip lock bag contained wa assumed correctly transpires dangerous drug namely ketamine',
#  'wa arrested exercised right remain silent',
#  'subsequent analysis content zip lock bag revealed contained 0 gramme powder containing 0 gramme ketamine',
#  'day arrest wa charged offence',
#  '0 february 0 appeared mr ricky chan permanent magistrate sitting eastern magistrate court',
#  'wa represented legal aid counsel',
#  'charge wa read particular follows',
#  'pang saulan charged 0 september 0 lok chau control point new territory hong kong unlawfully trafficked dangerous drug namely 0 gramme powder containing 0 gramme ketamine',
#  'day defendant pleaded guilty today ha confirmed plea',
#  'magistrate committed court sentence',
#  'prior summary fact wa read defendant court wa admitted',
#  'today ha accepted summary fact includes admission part wa trafficking quantity drug particularised charge',
#  'admitted fact drug valued 0 indeed correct',
#  'stand properly convicted charge',
#  'antecedent statement ha tendered prosecutor reveals defendant wa born 0 august 0 therefore 0 year age',
#  'time commission offence wa unemployed receipt comprehensive social service allowance',
#  'admission drug addict ha apparently abused ice ketamine since wa aged 0',
#  'prosecution ha provided court agreed miss wong behalf defendant criminal record summary',
#  'document demonstrates defendant ha since 0 court number occasion charged possession dangerous drug trafficking dangerous drug',
#  '0 wa sentenced trafficking dangerous drug magistrate court detained drug addiction treatment centre',
#  'subsequent release sentence wa 0 convicted possession dangerous drug trafficking dangerous drug 0 trafficking dangerous drug',
#  'occasion wa 0 november 0 wa sentenced 0 month imprisonment',
#  'perhaps significant conviction trafficking dangerous drug wa 0 wa sentenced court 0 year imprisonment',
#  'apparent sentence 0 trafficking dangerous drug must imposed shortly release 0 year term imprisonment imposed 0 july 0',
#  'defendant criminal record unenviable',
#  'indicates clearly whilst ha given opportunity past reform desist consumption dangerous drug also desist engaged trafficking dangerous drug ha apparently taken advantage opportunity',
#  'behalf miss barbara wong helpful written submission orally today ha advanced number argument submits would entitle court approach sentencing defendant significant degree leniency',
#  'come moment',
#  'miss wong readily accepts written submission orally appropriate guideline sentence trafficking ketamine set court appeal secretary justice v hii siew cheng reported 0 0 hklrd page 0 quantity drug defendant wa trafficking fall within fifth band guideline suggested range sentence traffic 0 0 gramme ketamine sentence 0 0 year',
#  'also accepts thing equal 0 gramme would normally attract starting point sentence 0 year trial',
#  'also accept miss wongs submission apart fact drug imported hong kong aggravating factor respect defendant course obvious factor first time ha committed offence trafficking dangerous drug',
#  'nevertheless circumstance appropriate increase starting point reason fact ha brought drug hong kong reason fact ha previously convicted trafficking dangerous drug',
#  'submission made miss wong written submission orally address specifically background defendant',
#  'point ha difficult life',
#  'accept',
#  'ha easy',
#  'accept occasion ha made effort turn life around nevertheless apparent criminal record effort short lived',
#  'accept miss wong ha pointed ha reached age 0 year age wish reunited daughter start new life together sister working vegetable stall',
#  'consideration take account determining appropriate level discount provided defendant starting point sentence',
#  'indicated given parameter guideline court appeal appropriate starting point sentence quantity ketamine 0 year imprisonment',
#  'miss wong submits increase normal discount given defendant background bleak life unique circumstance',
#  'emphasis woman need sympathy reason fact estranged daughter ha fallen prey influence others particular one former cohabitees ha led engaged past drug trafficking',
#  'apparent authority placed indeed authority court appeal including r v lau tak ming personal circumstance engage drug trafficking rarely provide basis increase discount plea guilty',
#  'case defendant ha past convicted offence',
#  'properly entitled full onethird discount starting point 0 year',
#  'mind factor would justify increasing discount normal onethird',
#  'starting point appropriate discount onethird would result sentence 0 year 0 month imprisonment',
#  'taken account matter advanced behalf miss wong unable say appropriate justified increase discount beyond indicated case sentence impose one 0 year 0 month imprisonment',
#  'present anna k lai spp department justice hksar wong szewing barbara assigned director legal aid accused date 0 april 0 0 hon',
#  'saw j',
#  'hksar v chan wing keung 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chan wingkeung',
#  '',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date',
#  '0 april 0 0',
#  'present',
#  'grace chan spp department justice hksar mr william allan instructed christopher k wong assigned director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court stand please chan wingkeung',
#  'chan wingkeung must know trafficking dangerous drug serious offence',
#  'harm dangerous drug hong kong throughout world well known',
#  'past 0 year country east country west drug become modern plaque',
#  'ruined ruining million people life',
#  'people benefit wicked cynical people control filthy trade',
#  'controlled people moral sense humanity',
#  'seriously doe legislature hong kong regard trafficking dangerous drug ha set maximum penalty life imprisonment',
#  '',
#  'fact dealing drug get share doe help',
#  'giving drug away nothing serious selling',
#  '',
#  'ketamine regarded hard drug',
#  'know counsel mr allan told court appeal set guideline judge sentence people traffic ketamine',
#  'also told judge expected stick guideline unless strong reason',
#  'tell case strong reason would justify departing guideline',
#  '',
#  'unfortunate court appeal revised guideline sentence upwards june 0 three month committed offence',
#  'duty clear apply guideline one set june last year',
#  '',
#  'note conviction possession dangerous drug 0 october last year sentenced 0 month imprisonment suspended 0 month',
#  'committed offence concerned 0 september last year power activate suspended sentence',
#  'also make clear increasing sentence going pas criminal record possession dangerous drug',
#  '',
#  'since trial started last monday noted strong support received family',
#  'rarely seen strong family support',
#  'truly lucky supportive family',
#  'sister letter wa read morning eloquently show love distress great foolishness ha caused',
#  'must abuse love trust future',
#  '',
#  'mitigation fact mitigation lie fact pleaded guilty',
#  'plea guilty always earn maker substantial reduction sentence',
#  'plea guilty indicates remorse demonstrates realism show acceptance responsibility offender wrongdoing',
#  'made plea guilty trial started could done magistrate court beginning trial last monday would able given onethird reduction sentence would received taken matter trial convicted jury',
#  '',
#  'plea guilty came trial started evidence ha led made ruling admissibility certain evidence give large discount',
#  'however discount receive substantial one',
#  'following court appeal guideline already spoken quantity ketamine wa 0 gramme stuff 0 gramme powder persisted plea guilty jury sworn trial gone full length jury convicted 0 count indictment would sentenced 0 year imprisonment',
#  'plea guilty reducing sentence 0 year 0 per cent discount',
#  '',
#  'therefore sentence imprisonment offence admitted committing one 0 year imprisonment',
#  'hksar v liu ka wai 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v liu kawai',
#  '',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date',
#  '0 april 0 0',
#  'present',
#  'leung sunyee rosaline spp department justice hksar mr ho kingman kenneth assigned director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court liu kawai aware trafficking form dangerous drug rightly considered serious offence hong kong',
#  'serious offence legislature ha set maximum penalty life imprisonment',
#  'counsel mr ho experienced told court appeal set guideline judge sentence people traffic dangerous drug',
#  'also told particular guideline applicable ketamine drug trafficked case',
#  '',
#  'obliged follow guideline unless strong reason tell strong reason case depart',
#  '',
#  'notice short criminal record includes offence possession dangerous drug',
#  'making clear aggravating increasing sentence previous conviction',
#  '',
#  'taken note letter put court letter mother ha put court say lucky supportive mother',
#  '',
#  'however mitigation lie fact cooperated custom excise officer pleaded guilty offence earliest possible opportunity magistrate court',
#  'doe indicate realism part also indicates degree remorse',
#  'well established people admit guilt entitled substantial discount sentence would otherwise received taken matter trial convicted jury',
#  '',
#  'following guideline already spoken taken matter trial convicted jury would mind sentence region 0 year imprisonment',
#  'would appropriate sentence man trafficked 0 gramme ketamine',
#  '',
#  'however plea guilty reducing sentence one third sentence 0 year imprisonment therefore sentence pas 0 year imprisonment',
#  'hksar v chan hei kam 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chan heikam',
#  '',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date',
#  '0 april 0 0',
#  'present',
#  'mr melwaney spp department justice hksar mr chau hingpang assigned director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court chan heikam drug addict man long criminal record offence involving misuse dangerous drug including previous conviction trafficking dangerous drug aware seriously law view offence',
#  'ha told morning counsel mr chau told know already clear guideline laid court appeal judge sentence people engage filthy trade',
#  'mr chau also told judge expected stick guideline unless strong reason',
#  'tell strong reason case',
#  '',
#  'nothing background circumstance commission offence way go towards mitigation',
#  'note extensive criminal record make clear aggravating sentence criminal record',
#  '',
#  'mitigation powerful mitigation admitted guilt early stage',
#  'pleaded guilty magistrate',
#  'show realism part',
#  'also indicates degree remorse well established entitled substantial discount sentence would received taken matter trial found guilty',
#  '',
#  'following guideline spoken taken matter trial pleaded guilty fought case jury found guilty would sent prison 0 year',
#  'plea guilty reducing sentence onethird',
#  'sentence offence therefore period imprisonment 0 year 0 month sentence pas upon',
#  'hksar v chun man 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v chun man',
#  '',
#  '',
#  'deputy high court judge lugarmawson court',
#  'date',
#  '0 april 0 0',
#  'present',
#  'mr vincent wong spp department justice hksar mr john ewan halley instructed director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court chunman must aware trafficking dangerous drug type rightly regarded serious criminal offence',
#  'told intention relation large quantity ice wa share friend',
#  'nevertheless trafficking dangerous drug regarded seriously case defendant sell drug profit',
#  'law concern much profit made dangerous drug great harm society caused circulation filthy substance',
#  '',
#  'ha told mitigation behalf counsel mr halley told guideline set judge sentence people traffic ice',
#  'guideline set long ago court appeal judge expected stick unless strong reason',
#  'tell strong reason case',
#  '',
#  'note lengthy criminal record make clear way aggravating increasing sentence fact criminal record',
#  '',
#  'mitigation pleaded guilty earliest opportunity cooperated authority well recognised entitled substantial discount sentence would received pleaded guilty taken matter trial found guilty jury',
#  'plea guilty indicates realism part',
#  'also indicates degree remorse',
#  '',
#  'tell found guilty jury trial contested case following guideline spoken would mind sentence 0 year imprisonment offence',
#  'however cooperation plea guilty permitted reduce sentence substantially',
#  '',
#  'reducing onethird sentence 0 year imprisonment sentence pas upon',
#  'hksar v choi sau ling 0 hkcfi 0 hccc 0 0 may 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v choi sauling',
#  '',
#  'hon beeson j date 0 may 0 0 present mr william stirling fiat hksar mr john marray instructed tai mak partner accused offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court defendant pleaded guilty two count trafficking dangerous drug',
#  'count 0 related 0 gramme mixture containing 0 gramme ketamine also 0 gramme cocaine',
#  'count 0 related',
#  '0 0 gramme nimetazepam form 0 tablet',
#  '',
#  '0 0 gramme midazolam form 0 tablet',
#  '',
#  '0 0 gramme crystalline solid containing 0 gramme methamphetamine hydrochloride ice',
#  '',
#  '0 0 gramme 0 ecstasy took form 0 tablet',
#  '',
#  '0 0 gramme mixture containing 0 gramme ketamine',
#  '',
#  '0 0 gramme solid containing 0 gramme cocaine',
#  'fact put court admitted defendant revealed defendant wa arrested consequence police ambush male friend returned flat wa living although wa tenant',
#  'two key flat seized defendant wa open door drug subject charge 0 found police searched handbag',
#  'arrest trafficking defendant told police carried dangerous drug somebody money',
#  'search warrant wa executed flat wa searched',
#  'led discovery drug subject 0 charge side table sitting room',
#  'arrested cautioned trafficking respect drug defendant said wa owner drug nothing friend',
#  'later video interview told interviewing officer become involved trafficking wa carrying drug instruction somebody else',
#  'defendant aged 0 year old',
#  'wa single time arrest',
#  'wa unemployed',
#  'ha two previous conviction',
#  'march 0 wa convicted magistracy trafficking ordered serve term drug addiction treatment centre',
#  'november 0 wa convicted making false statement immigration officer ordered perform 0 hour community service',
#  'mitigation wa advised wa separated husband ha 0 daughter cared husband parent wa process divorce',
#  'letter expressing defendant remorse wa put court letter parent sisterinlaw also put court requesting leniency term sentence',
#  'estimated value drug wa 0',
#  'basic reason defendant became involved offence wa wanted get quick money could retrieve daughter husband parent china rear daughter',
#  'record appears wa taking drug',
#  'serious offence involving substantial quantity drug',
#  'major drug cocaine ketamine combined range probably ketamine cocaine would amount 0 year starting point sentence',
#  'however note offence committed almost time note combined quantity ketamine cocaine substantial spread two charge',
#  'consider best way deal charge combine quantity cocaine ketamine',
#  'respect charge 0 serious component 0 gramme cocaine charged separately would require starting point 0 0 year',
#  'item 0 0 gramme ketamine charged alone would justify starting point 0 0 year',
#  'item 0 0 gramme ecstasy charged alone would justify starting point 0 year based new guideline ketamine ecstasymdmasee secretary justice v hii siew cheng 0 0 0 gramme ha range 0 0 year imprisonment',
#  '0 gramme ice item 0 would require starting point roughly 0 year 0 gramme ice ha range 0 0 year sentence',
#  'midazolam charge alone would discretion sentencer would based guideline methaqualone',
#  '0 gramme nimetazepam would also discretion sentencer possibly range twothirds methaqualone guideline',
#  'take starting point respect charge 0 year imprisonment',
#  'give defendant full discount onethird plea',
#  'sentenced 0 year imprisonment two charge',
#  'order sentence run concurrently',
#  '',
#  'hksar v liu ki chung 0 hkcfi 0 hccc 0 0 may 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar',
#  'v',
#  'liu kichung',
#  '',
#  '',
#  'hon beeson j',
#  'date',
#  '0 may 0 0',
#  'present',
#  'christal chan spp department justice hksar mr albert poon yingyin assigned director legal aid accused',
#  'offence',
#  'trafficking dangerous drug etc',
#  '',
#  'transcript audio recording sentence case',
#  'court defendant pleaded guilty committal 0 march 0 two count trafficking one count possession ketamine',
#  'total narcotic quantity two trafficking charge wa 0 gramme',
#  'narcotic quantity ketamine possession charge wa 0 gramme',
#  'today defendant confirmed plea confirmed also fact admitted committal',
#  'fact show defendant wa intercepted custom officer wa duty defendant appeared lift lobby residential building tsuen wan',
#  'wa searched found nine ziploc bag suspected dd',
#  'wa arrested cautioned caution said drug wa taking someone',
#  'drug subject 0 charge',
#  '',
#  'search wa made premise building defendant key',
#  'wa 0 floor',
#  'two large bag dangerous drug found minor packing paraphernalia',
#  'defendant wa cautioned',
#  'said dangerous drug wa take someone',
#  'drug subject second trafficking charge',
#  '',
#  'defendant wa taken residence elsewhere tsuen wan also key custom officer found five ziploc bag containing dangerous drug subject charge 0',
#  'defendant admitted drug consumption wa charged 0 charge possession respect drug',
#  '',
#  'government chemist later analysed suspected dangerous drug confirmed quantity ketamine set charge',
#  'total street value wa 0',
#  '',
#  'defendant ha criminal record start trafficking case 0 wa sentenced 0 month imprisonment',
#  '0 wa found guilty possession dangerous drug served term drug addiction treatment centre',
#  '',
#  'defendant 0 single',
#  'wa advised mitigation motherless since age 0 month father although supportive earlier failed supervise adequately long hour wa working',
#  '0 father remarried child wa born marriage',
#  'child health problem caused parent attention diverted child defendant wa supervised properly period',
#  'consequently wa influenced undesirable character',
#  'led drug offence 0 0 also much serious case today',
#  '',
#  'advised defendant disappointed feel ha failed family vow change way',
#  'say study prison try improve able lead productive life leaf prison',
#  '',
#  'although defendant told police antecedent statement wa drug abuser contradicted fact served term drug addiction treatment centre also admission counsel ha taking ketamine since wa 0 year old',
#  '',
#  'case occurred 0 june 0 come new ketamine guideline secretary justice v hii siew cheng another 0',
#  'note mitigation serious value defendant plea early plea entitled onethird discount',
#  '',
#  'considered charge quantity',
#  'combined quantity narcotic respect trafficking charge 0 within band 0 0 gramme',
#  'range sentence 0 0 year imprisonment adopt global starting point 0 year',
#  '',
#  'respect charge 0 0 take 0 starting point give full onethird discount plea guilty',
#  'sentence charge 0 year 0 month',
#  '',
#  'respect possession charge take starting point 0 year giving full discount plea sentence defendant 0 year 0 month imprisonment',
#  '',
#  'taking totality account order sentence charge 0 0 shall run concurrently 0 month sentence charge 0 shall run consecutively sentence charge 0 0',
#  'total sentence therefore 0 year imprisonment',
#  'hksar v ng ngo yu godwin 0 hkcfi 0 hccc 0 0 may 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v ng ngoyu godwin',
#  '',
#  'deputy high court judge geiser',
#  'date 0 may 0 0',
#  'present',
#  'mr melwaney spp department justice hksar mr phillip yeung senior la',
#  'counsel instructed messrs hoosenally neo accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court defendant committed court sentence pleaded guilty court charge trafficking dangerous drug namely 0 gramme powder containing 0 gramme ketamine',
#  'fact disclosed early hour 0 september last year hired locker mei foo bowling world centre seen placing paper bag inside locker',
#  'upon investigation bag wa found contain 0 bag ketamine together electronic scale empty plastic bag',
#  'subsequently told police drug imported china hong kong',
#  'paid 0 intended sell hong kong profit',
#  'read letter support submitted behalf written family member plead leniency',
#  'take account ha said behalf',
#  'however real mitigation plea guilty give credit',
#  'sentencing guideline trafficking ketamine increased case secretary justice anor v hii siew cheng application review 0 court appeal 0 0',
#  'amount drug subject matter charge come quite close top end 0 0 gramme bracket',
#  'adopt starting point sentence 0 year 0 month imprisonment',
#  'discount total 0 month reflect plea guilty arriving sentence 0 year 0 month imprisonment',
#  'hksar v tang yiu wing 0 hkcfi 0 hccc 0 0 may 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v tang yiuwing',
#  '',
#  'deputy high court judge geiser',
#  'date 0 may 0 0',
#  'present',
#  'mr vincent wong spp department justice hksar mr kamlesh arjan sadhwani instructed c lau co accused',
#  'offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court defendant pleaded guilty court single charge trafficking 0 gramme powder containing 0 gramme ketamine appear today sentence',
#  'summary fact agreed quite simply disclose afternoon 0 november last year stopped searched police discovered ketamine plastic bag carried',
#  'estimated retail value quantity ketamine told 0 thereabouts',
#  'poor criminal record',
#  'ha escaped notice amongst 0 previous conviction two prior drug conviction one trafficking dangerous drug',
#  'mitigation case plea guilty charge give full credit',
#  'sentencing guideline trafficking ketamine recently increased case secretary justice v hii siew cheng anor 0 hkca 0',
#  'trafficking quantity 0 0 gramme ketamine guideline indicate sentence 0 0 year imprisonment',
#  'accordingly adopt starting point sentence 0 year imprisonment',
#  'give full discount onethird reflect plea guilty arriving sentence 0 year 0 month imprisonment',
#  'hksar v wong wai tong 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v wong wai tong',
#  '',
#  'hon mcmahon j date 0 april 0 0 present mr p j power spp department justice hksar miss rita k instructed louis k pau co accused offence trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court defendant ha committed court sentence pursuant provision section 0 magistrate ordinance respect offence trafficking 0 gramme cocaine',
#  'fact case defendant wa seen police officer chi wo street jordan carrying paper bag',
#  'attracted suspicion wa stopped searched',
#  'inside bag wa carrying found dangerous drug',
#  'defendant wa arrested caution admitted knew drug cocaine said wa delivering person',
#  'bear mind principle expressed court appeal far sentencing large amount cocaine concerned case lau tak ming 0 hklr 0 pedro nel rojas 0 0 hkc 0 hksar v abdullah anwar abbas unreported cacc 0',
#  'take starting point sentence 0 year 0 month imprisonment',
#  'mitigation available defendant plea guilty regard warrant full discount sentence',
#  'accordingly sentence defendant 0 year 0 month imprisonment',
#  'hksar v yim yun choi 0 hkcfi 0 hccc 0 0 june 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar v yim yunchoi',
#  '',
#  'honourable mr justice v bokhary date 0 june 0 0 present mr vincent wong spp department justice hksar mr ian polson instructed legal aid department accused offence trafficking dangerous drug',
#  '',
#  'transcript audio recording sentence case',
#  '',
#  'court accused stand convicted one charge trafficking heroin',
#  'credit stand convicted plea guilty',
#  'quantity involved 0 gramme mixture containing 0 gramme heroin hydrochloride',
#  'view appropriate starting point quantity 0 year imprisonment',
#  'listened mitigation offered behalf counsel',
#  'also read letter written court',
#  'taken everything account particularly plea guilty sentence 0 year 0 month imprisonment',
#  '',
#  'hksar v lee yu chung 0 hkcfi 0 hccc 0 0 april 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar',
#  'v',
#  'lee yuchung',
#  '',
#  '',
#  'hon mcmahon j',
#  'date',
#  '0 april 0 0',
#  'present',
#  'rosaline leung spp department justice hksar mr caesar lo chilam assigned director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court defendant ha committed court sentence pursuant provision section 0 magistrate ordinance offence trafficking 0 gramme methamphetamine hydrochloride ice',
#  'fact case defendant brought drug hong kong 0 october 0 flight bombay',
#  'intended transfer flight manila drug concealed luggage detected custom officer',
#  'part drug found video projector inside defendant suitcase balance drug hidden lining suitcase',
#  '',
#  'defendant wa arrested subsequently admitted wa deliver drug person manila reward taiwanese 0 0',
#  '',
#  'given quantity drug involved considering guideline set attorney general v ching kwong hung 0 0 hklr 0 take initial starting point sentence 0 year imprisonment',
#  'take account international dimension offence enhance starting point sentence 0 year imprisonment',
#  'result final starting point sentence 0 year imprisonment',
#  '',
#  'defendant put forward mitigation economic family circumstance neither amount mitigation',
#  'doe however get full credit plea guilty starting point sentence reduced sentence 0 year 0 month imprisonment',
#  'hksar v fok chun man 0 hkcfi 0 hccc 0 0 may 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  'criminal case 0 0',
#  '',
#  'hksar',
#  'v',
#  'fok chunman',
#  '',
#  '',
#  'deputy high court judge line',
#  'date',
#  '0 may 0 0',
#  'present',
#  'mr phil chau counsel fiat hksar mr nigel de boinville instructed director legal aid accused',
#  'offence',
#  'trafficking dangerous drug',
#  'transcript audio recording sentence case',
#  'court stand please',
#  'sentence trafficking 0 gramme ketamine',
#  'appreciate court proceed basis guideline based weight nature drug',
#  'fall bracket 0 0 gramme attracting starting point trial 0 0 year imprisonment',
#  '',
#  'mitigation present someone ketamine user might well consumed drug would sold bulk someone actually selling small amount club would sell one person',
#  'wa put way akin courier added profit middle',
#  'nothing unrealistic description role act upon',
#  '',
#  'major mitigation course credit plea guilty shall give onethird discount starting point take',
#  'read letter written behalf',
#  'obviously case like consistency sentencing important limited weight',
#  'much weight give circumstance',
#  '',
#  'without letter mitigation heard counsel would looked starting point 0 year',
#  'would produce sentence 0 year 0 month onethird discount',
#  'matter entirely mathematical',
#  'never disputed fact',
#  'initial plea acknowledged possession sensible consideration ha resulted full plea guilty',
#  '',
#  'circumstance shall pas sentence 0 year 0 month imprisonment',
#  'judgment least could hope circumstance',
#  'hksar v ifeanyichukwu samuel 0 hkcfi 0 hccc 0 0 june 0',
#  '0',
#  'high court',
#  'hong kong special administrative region',
#  'court first instance',
#  ...]

# %%
xLengths = [len(word_tokenize(x)) for x in totalX]
# h = sorted(xLengths)  #sorted lengths 升序 第一个最小
# maxLength =h[len(h)-1]
maxLength = max(xLengths)
print("max input length is: ",maxLength)

# %%
# maxLength = h[int(len(h) * 0.70)]
# print("70% cover input sequence length up to",maxLength)

# %%
#给每个句子的词标上id
max_vocab_size = 30000
input_tokenizer = Tokenizer(max_vocab_size)
input_tokenizer.fit_on_texts(totalX)
input_vocab_size = len(input_tokenizer.word_index) + 1
print("input_vocab_size:",input_vocab_size)
#pre-padding and pre-truncating
totalX = np.array(pad_sequences(input_tokenizer.texts_to_sequences(totalX), maxlen=maxLength))

# %%
word_index = input_tokenizer.word_index

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

from gensim.models.keyedvectors import KeyedVectors

word_vectors = KeyedVectors.load_word2vec_format('./embedding/GoogleNews-vectors-negative300.bin', binary=True)

EMBEDDING_DIM=300
vocabulary_size=min(len(word_index)+1,max_vocab_size)
embedding_matrix = np.zeros((vocabulary_size, EMBEDDING_DIM))
count = 0
num_embedding = np.random.normal(0,np.sqrt(0.25),EMBEDDING_DIM)
for word, i in word_index.items():
    if i>=max_vocab_size:
        continue
    try:
        embedding_vector = word_vectors[word]
        embedding_matrix[i] = embedding_vector
    except KeyError:
        if word == "0":
            embedding_matrix[i] = num_embedding
        else:
            embedding_matrix[i] = np.random.normal(0,np.sqrt(0.25),EMBEDDING_DIM)

del(word_vectors)

# %%
# %%capture output
#Create Keras model
#num_categories 总标签数
num_categories = len(totalY[0])
num_categories
totalX.shape[0]

# %%
# Out:
# 298702

# %%
# %%capture output
prediction = []
prediction_index = []
early_stopping = EarlyStopping(patience=5)
histories = []
kf = KFold(n_splits=5)

# strategy = tf.distribute.MirroredStrategy()

for train_index, test_index in kf.split(totalX):
    model = Sequential()
    model.add(Embedding(input_vocab_size, EMBEDDING_DIM,input_length = maxLength, 
                        weights=[embedding_matrix],
                        trainable=False))
    # model.add(Embedding(input_vocab_size, embedding_dim,input_length = maxLength))
    # model.add(GRU(256, dropout=0.5, return_sequences=True))
    # model.add(GRU(256, dropout=0.5))
    model.add(Bidirectional(LSTM(256, dropout=0.5, return_sequences=True)))
    model.add(Bidirectional(LSTM(256, dropout=0.5)))
    model.add(Dense(num_categories, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])    

    
    trainX = totalX[train_index]
    trainY = totalY[train_index]
    histories.append(model.fit(trainX, trainY, validation_split=0.1, batch_size=512, epochs=50,callbacks=[early_stopping]))
    testX = totalX[test_index]
    testY = totalY[test_index]
    print(model.evaluate(testX, testY, batch_size=512))
    prediction_index.extend(data_files.loc[test_index][['neutral_citation','sentence_id']].values.tolist())
    prediction.extend(model.predict(testX))

output.show()
# Out:
# Epoch 1/50
# 421/421 [==============================] - 161s 382ms/step - loss: 0.3321 - binary_accuracy: 0.8486 - val_loss: 0.2603 - val_binary_accuracy: 0.8815
# Epoch 2/50
# 421/421 [==============================] - 179s 425ms/step - loss: 0.2866 - binary_accuracy: 0.8720 - val_loss: 0.2484 - val_binary_accuracy: 0.8897
# Epoch 3/50
# 421/421 [==============================] - 192s 455ms/step - loss: 0.2734 - binary_accuracy: 0.8787 - val_loss: 0.2404 - val_binary_accuracy: 0.8917
# Epoch 4/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2617 - binary_accuracy: 0.8845 - val_loss: 0.2410 - val_binary_accuracy: 0.8972
# Epoch 5/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2550 - binary_accuracy: 0.8883 - val_loss: 0.2361 - val_binary_accuracy: 0.8964
# Epoch 6/50
# 421/421 [==============================] - 200s 474ms/step - loss: 0.2492 - binary_accuracy: 0.8916 - val_loss: 0.2385 - val_binary_accuracy: 0.8931
# Epoch 7/50
# 421/421 [==============================] - 198s 469ms/step - loss: 0.2439 - binary_accuracy: 0.8937 - val_loss: 0.2370 - val_binary_accuracy: 0.8935
# Epoch 8/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2390 - binary_accuracy: 0.8961 - val_loss: 0.2384 - val_binary_accuracy: 0.8945
# Epoch 9/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2346 - binary_accuracy: 0.8987 - val_loss: 0.2362 - val_binary_accuracy: 0.8951
# Epoch 10/50
# 421/421 [==============================] - 200s 475ms/step - loss: 0.2312 - binary_accuracy: 0.9002 - val_loss: 0.2382 - val_binary_accuracy: 0.8940
# 117/117 [==============================] - 18s 156ms/step - loss: 0.2334 - binary_accuracy: 0.8995
# [0.23343437910079956, 0.8994660377502441]
# Epoch 1/50
# 421/421 [==============================] - 192s 456ms/step - loss: 0.3225 - binary_accuracy: 0.8529 - val_loss: 0.2507 - val_binary_accuracy: 0.8890
# Epoch 2/50
# 421/421 [==============================] - 201s 478ms/step - loss: 0.2812 - binary_accuracy: 0.8745 - val_loss: 0.2434 - val_binary_accuracy: 0.8945
# Epoch 3/50
# 421/421 [==============================] - 201s 476ms/step - loss: 0.2882 - binary_accuracy: 0.8737 - val_loss: 0.2387 - val_binary_accuracy: 0.8960
# Epoch 4/50
# 421/421 [==============================] - 200s 476ms/step - loss: 0.2619 - binary_accuracy: 0.8848 - val_loss: 0.2396 - val_binary_accuracy: 0.8953
# Epoch 5/50
# 421/421 [==============================] - 200s 476ms/step - loss: 0.2552 - binary_accuracy: 0.8879 - val_loss: 0.2334 - val_binary_accuracy: 0.8997
# Epoch 6/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2491 - binary_accuracy: 0.8911 - val_loss: 0.2324 - val_binary_accuracy: 0.8990
# Epoch 7/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2513 - binary_accuracy: 0.8890 - val_loss: 0.2314 - val_binary_accuracy: 0.9003
# Epoch 8/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2427 - binary_accuracy: 0.8945 - val_loss: 0.2325 - val_binary_accuracy: 0.8990
# Epoch 9/50
# 421/421 [==============================] - 197s 469ms/step - loss: 0.2369 - binary_accuracy: 0.8979 - val_loss: 0.2314 - val_binary_accuracy: 0.8986
# Epoch 10/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2338 - binary_accuracy: 0.8990 - val_loss: 0.2305 - val_binary_accuracy: 0.8986
# Epoch 11/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2300 - binary_accuracy: 0.9008 - val_loss: 0.2305 - val_binary_accuracy: 0.9008
# Epoch 12/50
# 421/421 [==============================] - 201s 478ms/step - loss: 0.2276 - binary_accuracy: 0.9021 - val_loss: 0.2279 - val_binary_accuracy: 0.9029
# Epoch 13/50
# 421/421 [==============================] - 200s 474ms/step - loss: 0.2249 - binary_accuracy: 0.9038 - val_loss: 0.2359 - val_binary_accuracy: 0.8982
# Epoch 14/50
# 421/421 [==============================] - 200s 475ms/step - loss: 0.2230 - binary_accuracy: 0.9047 - val_loss: 0.2373 - val_binary_accuracy: 0.8984
# Epoch 15/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2203 - binary_accuracy: 0.9061 - val_loss: 0.2385 - val_binary_accuracy: 0.8992
# Epoch 16/50
# 421/421 [==============================] - 200s 476ms/step - loss: 0.2160 - binary_accuracy: 0.9083 - val_loss: 0.2422 - val_binary_accuracy: 0.8983
# Epoch 17/50
# 421/421 [==============================] - 200s 474ms/step - loss: 0.2142 - binary_accuracy: 0.9087 - val_loss: 0.2374 - val_binary_accuracy: 0.8992
# 117/117 [==============================] - 18s 154ms/step - loss: 0.2433 - binary_accuracy: 0.8964
# [0.2432960867881775, 0.8964195251464844]
# Epoch 1/50
# 421/421 [==============================] - 190s 452ms/step - loss: 0.3158 - binary_accuracy: 0.8545 - val_loss: 0.2576 - val_binary_accuracy: 0.8855
# Epoch 2/50
# 421/421 [==============================] - 198s 471ms/step - loss: 0.2744 - binary_accuracy: 0.8767 - val_loss: 0.2437 - val_binary_accuracy: 0.8932
# Epoch 3/50
# 421/421 [==============================] - 198s 471ms/step - loss: 0.2597 - binary_accuracy: 0.8846 - val_loss: 0.2446 - val_binary_accuracy: 0.8940
# Epoch 4/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2512 - binary_accuracy: 0.8891 - val_loss: 0.2296 - val_binary_accuracy: 0.8984
# Epoch 5/50
# 421/421 [==============================] - 201s 478ms/step - loss: 0.2429 - binary_accuracy: 0.8926 - val_loss: 0.2281 - val_binary_accuracy: 0.8986
# Epoch 6/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2376 - binary_accuracy: 0.8957 - val_loss: 0.2326 - val_binary_accuracy: 0.8995
# Epoch 7/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2331 - binary_accuracy: 0.8990 - val_loss: 0.2320 - val_binary_accuracy: 0.8972
# Epoch 8/50
# 421/421 [==============================] - 198s 471ms/step - loss: 0.2277 - binary_accuracy: 0.9007 - val_loss: 0.2300 - val_binary_accuracy: 0.9004
# Epoch 9/50
# 421/421 [==============================] - 197s 467ms/step - loss: 0.2232 - binary_accuracy: 0.9034 - val_loss: 0.2288 - val_binary_accuracy: 0.8997
# Epoch 10/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2192 - binary_accuracy: 0.9056 - val_loss: 0.2329 - val_binary_accuracy: 0.8998
# 117/117 [==============================] - 17s 149ms/step - loss: 0.2754 - binary_accuracy: 0.8839
# [0.27537116408348083, 0.8838633894920349]
# Epoch 1/50
# 421/421 [==============================] - 192s 456ms/step - loss: 0.3256 - binary_accuracy: 0.8502 - val_loss: 0.2561 - val_binary_accuracy: 0.8861
# Epoch 2/50
# 421/421 [==============================] - 196s 466ms/step - loss: 0.2842 - binary_accuracy: 0.8729 - val_loss: 0.2506 - val_binary_accuracy: 0.8902
# Epoch 3/50
# 421/421 [==============================] - 200s 474ms/step - loss: 0.2700 - binary_accuracy: 0.8797 - val_loss: 0.2414 - val_binary_accuracy: 0.8977
# Epoch 4/50
# 421/421 [==============================] - 200s 475ms/step - loss: 0.2601 - binary_accuracy: 0.8857 - val_loss: 0.2331 - val_binary_accuracy: 0.9017
# Epoch 5/50
# 421/421 [==============================] - 200s 475ms/step - loss: 0.2525 - binary_accuracy: 0.8895 - val_loss: 0.2320 - val_binary_accuracy: 0.9021
# Epoch 6/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2466 - binary_accuracy: 0.8928 - val_loss: 0.2314 - val_binary_accuracy: 0.9018
# Epoch 7/50
# 421/421 [==============================] - 201s 477ms/step - loss: 0.2418 - binary_accuracy: 0.8951 - val_loss: 0.2316 - val_binary_accuracy: 0.8977
# Epoch 8/50
# 421/421 [==============================] - 198s 471ms/step - loss: 0.2432 - binary_accuracy: 0.8943 - val_loss: 0.2315 - val_binary_accuracy: 0.8999
# Epoch 9/50
# 421/421 [==============================] - 201s 478ms/step - loss: 0.2334 - binary_accuracy: 0.9001 - val_loss: 0.2317 - val_binary_accuracy: 0.9001
# Epoch 10/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2288 - binary_accuracy: 0.9021 - val_loss: 0.2284 - val_binary_accuracy: 0.9040
# Epoch 11/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2253 - binary_accuracy: 0.9034 - val_loss: 0.2352 - val_binary_accuracy: 0.9002
# Epoch 12/50
# 421/421 [==============================] - 197s 467ms/step - loss: 0.2210 - binary_accuracy: 0.9063 - val_loss: 0.2329 - val_binary_accuracy: 0.9009
# Epoch 13/50
# 421/421 [==============================] - 197s 467ms/step - loss: 0.2180 - binary_accuracy: 0.9079 - val_loss: 0.2374 - val_binary_accuracy: 0.8979
# Epoch 14/50
# 421/421 [==============================] - 197s 469ms/step - loss: 0.2151 - binary_accuracy: 0.9087 - val_loss: 0.2325 - val_binary_accuracy: 0.9001
# Epoch 15/50
# 421/421 [==============================] - 196s 465ms/step - loss: 0.2114 - binary_accuracy: 0.9109 - val_loss: 0.2324 - val_binary_accuracy: 0.9022
# 117/117 [==============================] - 18s 153ms/step - loss: 0.2534 - binary_accuracy: 0.8912
# [0.25338998436927795, 0.8911784291267395]
# Epoch 1/50
# 421/421 [==============================] - 189s 450ms/step - loss: 0.3183 - binary_accuracy: 0.8542 - val_loss: 0.3184 - val_binary_accuracy: 0.8563
# Epoch 2/50
# 421/421 [==============================] - 196s 466ms/step - loss: 0.2762 - binary_accuracy: 0.8757 - val_loss: 0.3087 - val_binary_accuracy: 0.8631
# Epoch 3/50
# 421/421 [==============================] - 200s 476ms/step - loss: 0.2612 - binary_accuracy: 0.8841 - val_loss: 0.3099 - val_binary_accuracy: 0.8632
# Epoch 4/50
# 421/421 [==============================] - 200s 474ms/step - loss: 0.2521 - binary_accuracy: 0.8887 - val_loss: 0.2962 - val_binary_accuracy: 0.8722
# Epoch 5/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2447 - binary_accuracy: 0.8927 - val_loss: 0.2938 - val_binary_accuracy: 0.8761
# Epoch 6/50
# 421/421 [==============================] - 199s 473ms/step - loss: 0.2388 - binary_accuracy: 0.8959 - val_loss: 0.2913 - val_binary_accuracy: 0.8740
# Epoch 7/50
# 421/421 [==============================] - 200s 475ms/step - loss: 0.3160 - binary_accuracy: 0.8576 - val_loss: 0.3442 - val_binary_accuracy: 0.8398
# Epoch 8/50
# 421/421 [==============================] - 198s 470ms/step - loss: 0.2828 - binary_accuracy: 0.8727 - val_loss: 0.3164 - val_binary_accuracy: 0.8560
# Epoch 9/50
# 421/421 [==============================] - 199s 474ms/step - loss: 0.2914 - binary_accuracy: 0.8660 - val_loss: 0.3085 - val_binary_accuracy: 0.8671
# Epoch 10/50
# 421/421 [==============================] - 200s 476ms/step - loss: 0.2625 - binary_accuracy: 0.8836 - val_loss: 0.3152 - val_binary_accuracy: 0.8662
# Epoch 11/50
# 421/421 [==============================] - 199s 472ms/step - loss: 0.2560 - binary_accuracy: 0.8869 - val_loss: 0.3023 - val_binary_accuracy: 0.8658
# 117/117 [==============================] - 18s 154ms/step - loss: 0.2541 - binary_accuracy: 0.8894
# [0.2541279196739197, 0.8894208073616028]

# %%
# import csv
# with open('extracted_factors_gru.csv', 'w') as ofile:
#     csv_writer = csv.writer(ofile, delimiter=',', quotechar='"')
#     csv_writer.writerow(['trial_id'] + list(data_files.columns)[2:13])
#     for idx, predict in zip(prediction_index, prediction):
#         csv_writer.writerow([idx] + list(predict>0.5))

# %%
# for idx, predict in zip(prediction_index, prediction):
#     print(np.where(predict>0.5), 1, 0)
#     break

# %%
import matplotlib.pyplot as plt


for history in histories:
    
    plt.figure()
    
    acc = history.history['binary_accuracy']
    val_acc = history.history['val_binary_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, label='Training acc')
    plt.plot(epochs, val_acc, label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.figure()

    plt.plot(epochs, loss,  label='Training loss')
    plt.plot(epochs, val_loss, label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plt.show()

# %%
import csv
with open('./output/extracted_importance_lstm_word2vec.csv', 'w') as ofile:
    csv_writer = csv.writer(ofile, delimiter=',', quotechar='"')
    csv_writer.writerow(list(data_files.columns)[:-1])
    for idx, predict in zip(prediction_index, prediction):
        csv_writer.writerow(idx + list(predict>0.5))
